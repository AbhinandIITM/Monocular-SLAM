# %%
import soundata

dataset = soundata.initialize('urbansound8k')
dataset.download(['all'])  # download the dataset
# Out:
# INFO: NumExpr defaulting to 16 threads.
# INFO: Downloading ['all'] to /home/abhi/sound_datasets/urbansound8k
# INFO: [all] downloading UrbanSound8K.tar.gz
# 5.61GB [38:10, 2.63MB/s]
